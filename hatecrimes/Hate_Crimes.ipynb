# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
# %matplotlib inline
import matplotlib.pyplot as plt
import fiona

# %%
states = gpd.read_file('/Users/amandajames/Desktop/NPR-Portfolio/14-homework-powerplants/cb_2016_us_state_500k/cb_2016_us_state_500k.shp')
states.crs = ({'proj': 'aea'})
states.head(10)
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD                  NAME  \
# 0  0400000US01   131173688951    4593686489    01   00               Alabama
# 1  0400000US02  1477946266785  245390495931    02   00                Alaska
# 2  0400000US04   294198560125    1027346486    04   00               Arizona
# 3  0400000US05   134771517596    2960191698    05   00              Arkansas
# 4  0400000US06   403501101370   20466718403    06   00            California
# 5  0400000US08   268429343790    1175112870    08   00              Colorado
# 6  0400000US09    12542638347    1815476291    09   00           Connecticut
# 7  0400000US10     5047194742    1398720828    10   00              Delaware
# 8  0400000US11      158364992      18633403    11   00  District of Columbia
# 9  0400000US13   149169848456    4741100880    13   00               Georgia
#
#   STATEFP   STATENS STUSPS                                           geometry
# ...

# %%
hate_crimes=pd.read_csv('hate_crimes.csv')
hate_crimes
# Out:
#                    state  median_household_income  share_unemployed_seasonal  \
# 0                Alabama                    42278                      0.060
# 1                 Alaska                    67629                      0.064
# 2                Arizona                    49254                      0.063
# 3               Arkansas                    44922                      0.052
# 4             California                    60487                      0.059
# 5               Colorado                    60940                      0.040
# 6            Connecticut                    70161                      0.052
# 7               Delaware                    57522                      0.049
# 8   District of Columbia                    68277                      0.067
# 9                Florida                    46140                      0.052
# 10               Georgia                    49555                      0.058
# ...

# %%
joined = states.merge(hate_crimes, left_on='NAME', right_on='state')
joined.head(2)
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD     NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00  Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00   Alaska      02
#
#     STATENS STUSPS                                           geometry  \
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
#
#               ...              share_unemployed_seasonal  \
# 0             ...                                  0.060
# 1             ...                                  0.064
#
#    share_population_in_metro_areas  share_population_with_high_school_degree  \
# 0                             0.64                                     0.821
# 1                             0.63                                     0.914
#
#    share_non_citizen  share_white_poverty  gini_index  share_non_white  \
# ...

# %%
fig,ax=plt.subplots()

# %%
joined.plot(figsize= (20,30),column='avg_hatecrimes_per_100k_fbi', cmap='Blues', linewidth=0.25, edgecolor='black', legend=False, scheme='Quantiles')
# Out:
# /usr/local/lib/python3.6/site-packages/pysal/esda/mapclassify.py:267: RuntimeWarning: invalid value encountered in greater
#   binIds += (x > l) * (x <= r) * k
# /usr/local/lib/python3.6/site-packages/pysal/esda/mapclassify.py:267: RuntimeWarning: invalid value encountered in less_equal
#   binIds += (x > l) * (x <= r) * k
# /usr/local/lib/python3.6/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)

# %%
plt.show();

# %%
plt.savefig('map.svg')

# %%
df[['','state']].sort_values(by=['avg_hatecrimes_per_100k_fbi'], ascending=False)
df.head(10)

# %%
ax.to_file("hatecrimemap.svg")

# %%
help()
